# %% [markdown]
# ## Validações de Qualidade de Dados
#
# Validações automatizadas para garantir a integridade dos dados após transformação.

# %%
from pipeline_utils import validar_silver

validar_silver(spark, "silver.taxidata.yellow_taxi_data")

# %%
validar_silver(spark, "silver.taxidata.green_taxi_data")
